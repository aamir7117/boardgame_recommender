# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
conn = sqlite3.connect('data/database.sqlite')

# %%
c = conn.cursor()

# %%
a = pd.read_sql('SELECT * FROM sqlite_master WHERE type="table";',conn)

# %%
a
# Out:
#     type                      name                  tbl_name  rootpage  \
# 0  table                BoardGames                BoardGames         2
# 1  table         bgg.ldaOut.topics         bgg.ldaOut.topics    128639
# 2  table      bgg.ldaOut.top.terms      bgg.ldaOut.top.terms    129442
# 3  table  bgg.ldaOut.top.documents  bgg.ldaOut.top.documents    129454
# 4  table                bgg.topics                bgg.topics    129468
#
#                                                  sql
# 0  CREATE TABLE "BoardGames" (\n  "row_names" TEX...
# 1  CREATE TABLE "bgg.ldaOut.topics" (\n  "row_nam...
# 2  CREATE TABLE "bgg.ldaOut.top.terms" (\n  "row_...
# 3  CREATE TABLE "bgg.ldaOut.top.documents" (\n  "...
# 4  CREATE TABLE "bgg.topics" (\n  "row_names" TEX...

# %%
dataset = pd.read_sql("SELECT * FROM BoardGames;",conn)

# %%
dataset.head(200)
# Out:
#     row_names game.id  game.type  \
# 0           1       1  boardgame
# 1           2       2  boardgame
# 2           3       3  boardgame
# 3           4       4  boardgame
# 4           5       5  boardgame
# 5           6       6  boardgame
# 6           7       7  boardgame
# 7           8       8  boardgame
# 8           9       9  boardgame
# 9          10      10  boardgame
# 10         11      11  boardgame
# 11         12      12  boardgame
# 12         13      13  boardgame
# 13         14      14  boardgame
# 14         15      15  boardgame
# 15         16      16  boardgame
# 16         17      17  boardgame
# 17         18      18  boardgame
# 18         19      19  boardgame
# 19         20      20  boardgame
# 20         21      21  boardgame
# 21         22      22  boardgame
# 22         23      23  boardgame
# 23         24      24  boardgame
# 24         25      25  boardgame
# 25         26      26  boardgame
# 26         27      27  boardgame
# ...

# %%
out_topics = pd.read_sql("SELECT * FROM 'bgg.ldaOut.topics';",conn)

# %%
out_topics.head(200)
# Out:
#                        row_names  topics(bgg.ldaOut)
# 0                     Die.Macher                   8
# 1                   Dragonmaster                   5
# 2                        Samurai                  22
# 3                 Tal.der.Könige                   4
# 4                        Acquire                   4
# 5             Mare.Mediterraneum                  22
# 6                      Cathedral                  24
# 7              Lords.of.Creation                   9
# 8                   El.Caballero                   7
# 9                      Elfenland                  25
# 10                      Bohnanza                   8
# 11                            Ra                  10
# 12                         Catan                  23
# 13                        Basari                   8
# 14              Cosmic.Encounter                   1
# 15                     MarraCash                   8
# 16                    Button.Men                  20
# ...

# %%
top_terms = pd.read_sql("SELECT * FROM 'bgg.ldaOut.top.terms';",conn)

# %%
top_terms.head(200)
# Out:
#     row_names  topic                                 term      beta
# 0           1      1                    Bluffing.category  0.183436
# 1           2      1                   Deduction.category  0.164224
# 2           3      1                Partnerships.mechanic  0.080226
# 3           4      1                   PartyGame.category  0.066343
# 4           5      1              Murder.Mystery.category  0.048674
# 5           6      1                 RolePlaying.mechanic  0.040120
# 6           7      1                      Voting.mechanic  0.037596
# 7           8      1           PlayerElimination.mechanic  0.035072
# 8           9      1            Betting.Wagering.mechanic  0.033108
# 9          10      1          Spies.SecretAgents.category  0.029743
# 10         11      2              ScienceFiction.category  0.251080
# 11         12      2                  Miniatures.category  0.131499
# 12         13      2  ActionPointAllowanceSystem.mechanic  0.086690
# ...

# %%
top_docs = pd.read_sql("SELECT * FROM 'bgg.ldaOut.top.documents';",conn)

# %%
top_docs.head(200)
# Out:
#     row_names                                           document  topic  \
# 0           1                           The.Lounge..A.Mafia.Game      1
# 1           2                Ultimate.Werewolf..Ultimate.Edition      1
# 2           3  Ultimate.Werewolf..Deluxe.Edition.For.Kickstarter      1
# 3           4                                           Werewolf      1
# 4           5                     Παλέρμο..Το.Μεγάλο.Ξεκαθάρισμα      1
# 5           6                Ultimate.Werewolf..Whitebox.Edition      1
# 6           7                                  Una.Notte.da.Lupi      1
# 7           8                                    Mafia..Vendetta      1
# 8           9        The.Werewolves.of.Miller.s.Hollow..The.Pact      1
# 9          10                  Ultimate.Werewolf..Deluxe.Edition      1
# 10         11                                      Titan.Legions      2
# 11         12                             De.Bellis.Antiquitatis      2
# ...

# %%
topics = pd.read_sql("SELECT * FROM 'bgg.topics';",conn)

# %%
topics.head(200)
# Out:
#     row_names game.id  game.type  details.maxplayers  details.maxplaytime  \
# 0           1       1  boardgame                 5.0                240.0
# 1           2       2  boardgame                 4.0                 30.0
# 2           3       3  boardgame                 4.0                 60.0
# 3           4       4  boardgame                 4.0                 60.0
# 4           5       5  boardgame                 6.0                 90.0
# 5           6       6  boardgame                 6.0                240.0
# 6           7       7  boardgame                 2.0                 20.0
# 7           8       8  boardgame                 5.0                120.0
# 8           9       9  boardgame                 4.0                 90.0
# 9          10      10  boardgame                 6.0                 60.0
# 10         11      11  boardgame                 7.0                 45.0
# 11         12      12  boardgame                 5.0                 60.0
# ...

# %%
dataset.iloc[[12],:]
# Out:
#    row_names game.id  game.type  \
# 12        13      13  boardgame
#
#                                   details.description  \
# 12  In Catan (formerly The Settlers of Catan), pla...
#
#                                    details.image  details.maxplayers  \
# 12  //cf.geekdo-images.com/images/pic2419375.jpg                 4.0
#
#     details.maxplaytime  details.minage  details.minplayers  \
# 12                120.0            10.0                 3.0
#
#     details.minplaytime             ...              \
# 12                 60.0             ...
#
#    stats.family.arcade.bayesaverage  stats.family.arcade.pos  \
# 12                              NaN                      NaN
#
#    stats.family.atarist.bayesaverage  stats.family.atarist.pos  \
# 12                               NaN                       NaN
#
#    stats.family.commodore64.bayesaverage stats.family.commodore64.pos  \
# 12                                   NaN                          NaN
#
# ...

# %%
dataset['details.description'][12]
# Out:
# u"In Catan (formerly The Settlers of Catan), players try to be the dominant force on the island of Catan by building settlements, cities, and roads. On each turn dice are rolled to determine what resources the island produces. Players collect these resources (cards)&mdash;wood, grain, brick, sheep, or stone&mdash;to build up their civilizations to get to 10 victory points and win the game.&#10;&#10;Setup includes randomly placing large hexagonal tiles (each showing a resource or the desert) in a honeycomb shape and surrounding them with water tiles, some of which contain ports of exchange. Number disks, which will correspond to die rolls (two 6-sided dice are used), are placed on each resource tile. Each player is given two settlements (think: houses) and roads (sticks) which are, in turn, placed on intersections and borders of the resource tiles. Players collect a hand of resource cards based on which hex tiles their last-placed house is adjacent to. A robber pawn is placed on the d
# ...

# %%
dataset.isnull().sum()
# Out:
# row_names                                    0
# game.id                                      0
# game.type                                    0
# details.description                          0
# details.image                             6892
# details.maxplayers                           3
# details.maxplaytime                          3
# details.minage                               3
# details.minplayers                           3
# details.minplaytime                          3
# details.name                                 0
# details.playingtime                          3
# details.thumbnail                         6892
# details.yearpublished                        3
# attributes.boardgameartist               55735
# attributes.boardgamecategory              1531
# attributes.boardgamecompilation          88105
# attributes.boardgamedesigner             11883
# attributes.boardgameexpansion            72613
# attributes.boardgamefamily               40232
# ...
